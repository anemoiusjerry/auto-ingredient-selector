# %%
import sqlalchemy as db

# %%
# Path to database
db_file = "C:/users/jerry/Desktop/RestoredToEden.db"

# Set up SQLAlchemy connection
engine = db.create_engine('sqlite:///' + db_file)
cnxn = engine.connect()

metadata = db.MetaData()
metadata.reflect(cnxn)

InformationSheet = metadata.tables['InformationSheet']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-ec5b1e623831> in <module>
#       9 metadata.reflect(cnxn)
#      10
# ---> 11 InformationSheet = metadata.tables['InformationSheet']
#
# KeyError: 'InformationSheet'

# %%
def get_table_contents(table):
    """ inputs: table containing items to query
        returns: dict of {col headings: col values}
    """
    query = db.select([table])
    headings = cnxn.execute(query).keys()
    query = db.select([table])
    values = cnxn.execute(query).fetchone()

    contents = {}
    # Create dict struct
    for i in range(len(headings)):
        contents[headings[i]] = values[i]

    return contents

get_table_contents(InformationSheet).values()
# Out:
# dict_values(['Simple instructions can be found on each product. [customer name], [detailed description inserted here from file]', 'It is recommended that you strip back your skincare routine to the basics and start with a blank slate. It is also recommended that you do not use other new skincare products while you are testing our products on your skin. The reason for this is you will not really know which of the products caused a reaction if you introduce too many at one time. If you usually do not have a problem with reactions on your skin, you should not have a reaction.', 'Store below 25 degrees celsius. Keep out of direct sunlight. Store in a dry place. Do not allow water to enter your product.', 'dwwd', 'We go to great lengths to hand select every ingredient. Please do not hesitate to let us know if you are not having the desired effect after using this product for the first 6 weeks. We will ensure that we analyse your needs further and make the necessary adjustments to your formulation. ', 'This blend must be used within. months of blending. Date Blended: [date blended] Best Before Date: [best before date]'])

# %%
def get_col_names(table):
    query = db.select([table])
    return cnxn.execute(query).keys()

get_col_names(InformationSheet)
# Out:
# ['Recommendations For Use',
#  'For Best Results',
#  'Care & Storage Instructions',
#  'Directions & Warnings Before Use',
#  'Our promises to you',
#  'Used By & Best Before Date']

# %%
def insert_query(table, data):
    """ data: dictionary of column name and its value
    """
    query = table.insert().values(data)
    cnxn.execute(query)
    
def update_query(table, data):
    query = db.update(table).values(data)
    cnxn.execute(query)

# %%
data = {"Recommendations For Use": "Simple instructions can be found on each product.  [customer name], [detailed description inserted here from file]",
        "For Best Results": "It is recommended that you strip back your skincare routine to the basics and start with a blank slate.  It is also recommended that you do not use other new skincare products while you are testing our products on your skin.  The reason for this is you will not really know which of the products caused a reaction if you introduce too many at one time.  If you usually do not have a problem with reactions on your skin, you should not have a reaction.",
        "Care & Storage Instructions": "Store below 25 degrees celsius.  Keep out of direct sunlight.  Store in a dry place.  Do not allow water to enter your product.",
        "Directions & Warnings Before Use": "Store below 25 degrees celsius.  Keep out of direct sunlight.  Store in a dry place.  Do not allow water to enter your product.",
        "Our promises to you": "We go to great lengths to hand select every ingredient.  Please do not hesitate to let us know if you are not having the desired effect after using this product for the first 6 weeks.  We will ensure that we analyse your needs further and make the necessary adjustments to your formulation.\nWe select only natural and organic ingredients in order to formulate products that are not only gentle on your skin but are also effective.  Each of our ingredients goes through a selection process to ensure the highest quality.\nPlease do not hesitate to contact us if you have any questions or concerns about any of our products.  We would be happy to help.",
        "Used By & Best Before Date": "This blend must be used within …. months of blending.\nDate Blended: [date blended]\nBest Before Date: [best before date]"
       }

update_query(InformationSheet, data)

# %%
query = db.select([InformationSheet])
paragraphs = cnxn.execute(query).fetchone()
col_names = get_col_names(InformationSheet)

paragraphs[-1]
# Out:
# 'This blend must be used within …. months of blending.\nDate Blended: [date blended]\nBest Before Date: [best before date]'

# %%
import copy
# Delete column
metadata = db.MetaData()
metadata.reflect(cnxn)
InformationSheet = metadata.tables['InformationSheet']

# Get columns to keep
col_drop = ["new_column_name", "Field8"]
new_cols = []
for column in InformationSheet.columns:
    if not (column.name in col_drop):
        column_copy = copy.deepcopy(column)
        column_copy.table = None
        new_cols.append(column_copy)

# Save data to keep
new_content = get_table_contents(InformationSheet)
del new_content["Field8"]
del new_content["new_column_name"]

#new_table = db.Table("copy", metadata, *(column for column in new_cols))

# %% [markdown]
# # Section allows editing of information sheet
# Store info in an excel sheet

# %%
from openpyxl import load_workbook
from datetime import *
import pandas as pd
import os

# %%
class ButtonWrapper:
    def __init__(self, button, label, text_box):
        self.df = None
        self.button = button
        self.label = label
        self.text_box = text_box
        
        self.button.clicked.connect(self.del_section)
        
    def del_section(self):
        df = pd.DataFrame({self.label.text(): [self.text_box.toPlainText()]})
        self.label.deleteLater()
        self.text_box.deleteLater()
        self.button.deleteLater()
        
        self.df = df

# %%
import sys
from PySide2.QtWidgets import *

paragraphs_df = pd.read_excel(info_sheet_path)

class Form(QDialog):
    def __init__(self, contents, parent=None):
        super(Form, self).__init__(parent)
        
        self.paragraphs_df = contents
        
        self.setWindowTitle("Information Sheet Editor")
        self.resize(700, 500)
        self.layout = QGridLayout()

        # Save button
        button = QPushButton("Save")
        button.clicked.connect(self.refresh)
        self.layout.addWidget(button, 0, 0)

        # Add new section button
        button = QPushButton("Add section")
        button.clicked.connect(self.add_section)
        self.layout.addWidget(button, 1, 0)
        
        self.del_buttons = []
        for i in range(contents.shape[1]):
            # Create label
            l = QLabel(list(contents)[i])
            self.layout.addWidget(l, 2*i+2, 0)
            
            # Create text boxes
            t = QTextEdit(contents.iloc[0,i])
            self.layout.addWidget(t, 2*i +2 + 1, 0)
            
            button = QPushButton("del")
            self.del_buttons.append(ButtonWrapper(button, l, t))
            self.layout.addWidget(button, 2*i +2 + 1, 1)

#         # Delete section button
#         button = QPushButton("Delete section")
#         button.clicked.connect(self.del_section)
#         self.layout.addWidget(button)

        # Set dialog layout
        self.setLayout(self.layout)

    def add_section(self):
        dialog = QDialog()
        dialog.setWindowTitle("New Section")
        layout = QVBoxLayout()

        # New section heading
        l = QLabel("Section Title")
        layout.addWidget(l)
        e = QLineEdit()
        layout.addWidget(e)

        # New section content
        l_content = QLabel("Section Content")
        layout.addWidget(l_content)
        e_content = QTextEdit()
        layout.addWidget(e_content)

        # Button adds new info to SQLite
        button = QPushButton("Ok!")
        button.clicked.connect(lambda: self.add_N_close(dialog, e.text(), e_content.toPlainText()))

        dialog.setLayout(layout)
        dialog.exec_() 

    def add_N_close(self, dialog, n_heading, n_body):
        new_section_df = pd.DataFrame({n_heading: [n_body]})
        self.paragraphs_df = pd.concat([paragraphs_df, new_section_df], axis=1)
        
        l = QLabel(n_heading)
        t = QTextEdit(n_body)
        self.text_boxes.append(t)
        
        # Insert new section before the buttons
        print(self.layout.count())
        pos = self.layout.rowCount()
        self.layout.addWidget(l, pos, 0)
        self.layout.addWidget(t, pos+1, 0)

        dialog.close()
    
     
    def refresh(self):
        for b_wrap in self.del_buttons:
            if b_wrap.df != None:
                print(b_wrap.df)
        # Export paragraph dfs to xlsx to load later
        #self.paragraphs_df.to_excel("test.xlsx")

# %%
# Read current info sheet
working_dir = os.getcwd()
info_sheet_path = working_dir + r"\BespokeAutoSystem\InformationSheet.xlsx"
paragraphs_df = pd.read_excel(info_sheet_path)
paragraphs_df
# Out:
#   Recommendations For Use For Best Results Care & Storage Instructions  \
# 0                     eek        Saradomin                       Zaros
#
#   Directions & Warnings Before Use Our promises to you  \
# 0                          Zamorak              Bandos
#
#   Used By & Best Before Date
# 0                    Armadyl

# %% [markdown]
# # This Section opens excel worksheet template and writes to it!
# 1. Read input:
#     - Ingredient list
#     - Product name
#     - Product type
#     - Customer name
# 2. Open corresponding excel template to product type
# 3. Fill out header information
# 4. Go through ingredients and fill in main table entries
# 5. Run calc. function to fill grams based on product formulation
# 6. Output .xlsx

# %%
from openpyxl import load_workbook
from datetime import *
import pandas as pd
import os
import re

# %%
def ingredient_weight_real(ingredients, prod_type, ingredients_df):
    # Get template folder path
    path = os.getcwd() + "\\Formulation Templates\\"
    template_path = path + prod_type + " Worksheet.xlsx"
    # Load the excel sheet
    workbook = load_workbook(filename=template_path)
    sheet = workbook.active

    # Get ingredient % dict
    ww_dict, realloc_dict, phase_dict, assigned_vals, EOF = get_misc_items(sheet)
    print(assigned_vals)
    # Fill main table entries
    for i in range(len(ingredients)):
        ingredient_name = ingredients[i]

        # Get ingredient types ???????????/// Waiting for answer to simplify column
        type_str = str(ingredients_df.loc[ingredient_name]["TYPE OF INGREDIENT"]).lower()
        type_list = re.split("\s*[,]\s*", type_str)
        ingredient_type = type_list[-1]

        if "essential oil" in ingredient_type:
            ingredient_type = "eo " + ingredients_df.loc[ingredient_name]["ESSENTIAL OIL NOTE"].lower()
        
        if ingredient_type in ww_dict:
            if len(ww_dict[ingredient_type]) > 1:
                assigned_vals[ingredient_name] = ww_dict[ingredient_type].pop(0)
            else:
                assigned_vals[ingredient_name] = ww_dict[ingredient_type][0]

    print(assigned_vals)
    # Scale to 100
    tot = sum(assigned_vals.values())
    print(tot)
    if tot > 100:
        for key in assigned_vals.keys():
            assigned_vals[key] = assigned_vals[key] * 100/tot
    elif tot < 100:
        leftover = 100 - tot
        for key in assigned_vals.keys():
            assigned_vals[key] = assigned_vals[key] + leftover * assigned_vals[key]/tot
    else:
        pass
    return assigned_vals

# %%
def get_misc_items(sheet):
        ww_dict = {} 
        realloc_dict = {}
        phase_dict = {}
        assigned_vals = {}
        
        i = 7
        # Record the w/w% for all types
        while sheet[f"C{i}"].value != None:
            i_type = sheet[f"B{i}"].value.lower()
            if i_type not in ww_dict.keys():
                ww_dict[i_type] = [sheet[f"D{i}"].value]
            else:
                ww_dict[i_type].append(sheet[f"D{i}"].value)
            
            if ("this ingredient doesn't change" in sheet[f"B{i}"].value.lower()) or ("does not change" in sheet[f"B{i}"].value.lower()):
                assigned_vals[sheet[f"B{i}"].value] = sheet[f"D{i}"].value
            else:
                realloc_dict[f"D{i}"] = sheet[f"D{i}"].value
                
            phase_dict[i_type] = sheet[F"C{i}"].value
            i += 1
        EOF = i
        return ww_dict, realloc_dict, phase_dict, assigned_vals, EOF
    
def too_many_slots(realloc_dict, sheet):   
    # Write 0s to unallocated rows to make for delete
    for cell in realloc_dict.keys():
        sheet[cell] = 0 
        
    i = 7
    while sheet.cell(row=i, column=3).value != None:
        if sheet.cell(row=i, column=4).value == 0:
            sheet.delete_rows(i)
        else:
            i += 1
    return sheet

def too_few_slots(leftovers, phase_dict, EOF, sheet):

    for ingredient, weight in leftovers.items():
        if "ingredient doesn't change" in ingredient:
            continue
        # Get ingredient type and assign corresponding w/w%
        i_type = ingredients_df.loc[ingredient]["TYPE OF INGREDIENT"].lower().split(",")[-1] 
        # Insert at end of sheet
        sheet.insert_rows(EOF)
        # INCI name
        sheet[f"A{EOF}"] = ingredients_df.loc[ingredient]["INGREDIENT INCI NAME"]
        # name
        sheet[f"B{EOF}"] = ingredient  
        # Phase
        sheet[f"C{EOF}"] = phase_dict[i_type]
        # w/w%
        sheet[f"D{EOF}"] = weight
    return sheet

# %%
prod_type = "Day Cream"
ingredients = re.split("\s*[,]\s*", 
                       "Horse Chestnut Extract, Kaolin Clay, Aloe Vera Juice, Carrot Seed Essential Oil")

# prod_type = "Oil Cleanser"
# ingredients = ["Avocado", "Argan Oil", "Apricot Kernel Oil",
#               "Bergamot Essential Oil", "Cypress Essential Oil", "Frankincense Olibanum Essential Oil"]


customer_name = "Jane Doe"
# Load ingredients_df
ingredFname = "C:/Users/jerry/Desktop/Restored To Eden/Ingredients.csv"
ingredients_df = pd.read_csv(ingredFname)
ingredients_df.fillna("", inplace = True)
ingredients_df.set_index("INGREDIENT COMMON NAME", inplace=True)

# Get template folder path
path = os.getcwd() + "\\Formulation Templates\\"
template_path = path + prod_type + " Worksheet.xlsx"

# %%
# Load the excel sheet
workbook = load_workbook(filename=template_path)
sheet = workbook.active

ww_dict, realloc_dict, phase_dict, assigned_vals, EOF = get_misc_items(sheet)
# Get assigned values
assigned_vals = ingredient_weight_real(ingredients, prod_type, ingredients_df)
# Fill header info
sheet["B1"] = customer_name
sheet["B2"] = prod_type
sheet["B5"] = 100  # placeholder (varies)

print(assigned_vals)
i=0
# Fill main table entries
while len(assigned_vals) > 0:
    # End loop if all slots have been assigned
    if len(realloc_dict) <= 0:
        sheet = too_few_slots(assigned_vals, phase_dict, EOF, sheet)
        break
    
    ingredient_name = list(assigned_vals.keys())[i] 
    # Pass if static ingredient
    if "ingredient doesn't change" in ingredient_name.lower() or "does not change" in ingredient_name.lower():
        print(ingredient_name)
        j=7
         # Insert ingredient into a corresponding row
        while sheet[f"C{j}"].value != None:
            # Fill cell if ingredient is same type as template
            if ingredient_name.lower() == sheet[f"B{j}"].value.lower():
                # Fill w/w%
                sheet[f"D{j}"] = assigned_vals[ingredient_name]

                realloc_dict.pop(f"D{j}", None)
                assigned_vals.pop(ingredient_name)
                break 
            j+=1
    
        continue
    
 
    # Get ingredient types ???????????/// Waiting for answer to simply column
    type_list = str(ingredients_df.loc[ingredient_name]["TYPE OF INGREDIENT"]).lower()
    ingredient_type = re.split("\s*[,]\s*", type_list)[-1]

    if "essential oil" in ingredient_type:
        ingredient_type = "eo " + ingredients_df.loc[ingredient_name]["ESSENTIAL OIL NOTE"].lower()
    
    print(ingredient_type)
    print(ingredient_name)
    j = 7  # reset j
    # Insert ingredient into a corresponding row
    while sheet[f"C{j}"].value != None:
        # Fill cell if ingredient is same type as template
        if ingredient_type == sheet[f"B{j}"].value.lower():
            # Fill INCI
            sheet[f"A{j}"] = ingredients_df.loc[ingredient_name]["INGREDIENT INCI NAME"]
            # Fill ingredient name
            sheet[f"B{j}"] = ingredient_name
            # Fill w/w%
            sheet[f"D{j}"] = assigned_vals[ingredient_name]
            # Fill needs targted column if applicable
            try:
                if sheet[f"F{6}"].value.lower() == "needs targetting":
                    sheet[f"F{6}"] = ingredients_df.loc[ingredient_name]["SKIN PROBLEM"]
            except:
                print("No needs targetting column.")
                
            realloc_dict.pop(f"D{j}", None)
            assigned_vals.pop(ingredient_name)
            break 
        j+=1
        
    # if ingredient not assigned then +i
    if ingredient_name in assigned_vals.keys():
        i+=1

    
# Reallocate surplus %
if len(realloc_dict) > 0:
    sheet = too_many_slots(realloc_dict, sheet)
# Out:
# {'Humectant [this ingredient does not change]': 2.0, 'Emulsifier [this ingredient does not change]': 6.0, 'Preservative [this ingredient does not change]': 1.0, 'Antioxidant [this ingredient does not change]': 0.5}
# {'Humectant [this ingredient does not change]': 2.0, 'Emulsifier [this ingredient does not change]': 6.0, 'Preservative [this ingredient does not change]': 1.0, 'Antioxidant [this ingredient does not change]': 0.5, 'Horse Chestnut Extract': 5.0, 'Aloe Vera Juice': 5.0, 'Carrot Seed Essential Oil': 0.6}
# 20.1
# {'Humectant [this ingredient does not change]': 9.950248756218905, 'Emulsifier [this ingredient does not change]': 29.850746268656717, 'Preservative [this ingredient does not change]': 4.975124378109452, 'Antioxidant [this ingredient does not change]': 2.487562189054726, 'Horse Chestnut Extract': 24.87562189054726, 'Aloe Vera Juice': 24.87562189054726, 'Carrot Seed Essential Oil': 2.985074626865672}
# Humectant [this ingredient does not change]
# Emulsifier [this ingredient does not change]
# Preservative [this ingredient does not change]
# Antioxidant [this ingredient does not change]
# aqueous high performance
# Horse Chestnut Extract
# No needs targetting column.
# aqueous high performance
# Aloe Vera Juice
# No needs targetting column.
# eo middle
# Carrot Seed Essential Oil
# No needs targetting column.

# %%
# Print spreadsheet:
k=7
while (k<24):
    print(k)
    print(sheet[f"B{k}"].value + ": " + str(sheet[f"D{k}"].value))
    k+=1
# Out:
# 7
# Anhydrous [this ingredient doesn't change]: 66.5
# 8
# Avocado: 13.009540329575023
# 9
# Argan Oil: 13.009540329575023
# 10
# Bergamot Essential Oil: 0.4336513443191674
# 11
# Cypress Essential Oil: 0.6938421509106678
# 12
# Frankincense Olibanum Essential Oil: 0.4336513443191674
# 13
# Antioxidant [this ingredient doesn't change]: 2
# 14
# Apricot Kernel Oil: 13.009540329575023
# 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-938e25374fba> in <module>
#       3 while (k<24):
#       4     print(k)
# ----> 5     print(sheet[f"B{k}"].value + ": " + str(sheet[f"D{k}"].value))
#       6     k+=1
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
## Export
save_path = "C:/users/jerry/Desktop/Restored To Eden/test forms/"
workbook.save(save_path + customer_name + "-" + prod_type + ".xlsx")

# %%
from __future__ import print_function
import pickle
import os.path
from googleapiclient.discovery import *
from google_auth_oauthlib.flow import *
from google.auth.transport.requests import *
import io
from googleapiclient.http import *
import pandas as pd

# If modifying these scopes, delete the file token.pickle.
SCOPES = ['https://www.googleapis.com/auth/drive',
          'https://www.googleapis.com/auth/spreadsheets']

"""Shows basic usage of the Drive v3 API.
Prints the names and ids of the first 10 files the user has access to.
"""
creds = None
# The file token.pickle stores the user's access and refresh tokens, and is
# created automatically when the authorization flow completes for the first
# time.
if os.path.exists('token.pickle'):
    with open('token.pickle', 'rb') as token:
        creds = pickle.load(token)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            'credentials.json', SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.pickle', 'wb') as token:
        pickle.dump(creds, token)

service = build('drive', 'v3', credentials=creds)

# %%
def gdrive_get_file(filename):
    results = service.files().list(q=f"name contains '{filename}'",
                    spaces='drive',
                    fields='nextPageToken, files(id, name, mimeType)').execute()

    file_id = results.get('files', [])[0]['id']
    file_type = results.get('files', [])[0]['mimeType']
    
    # Check file type and send request appropriately
    if 'application/vnd.google-apps' in file_type:
        request = service.files().export_media(fileId=file_id, 
           mimeType="application/vnd.openxmlformats-officedocument.spreadsheetml.sheet")
    else:
        print(file_id)
        request = service.files().get_media(fileId=file_id)
        
    fh = io.BytesIO()
    downloader = MediaIoBaseDownload(fh, request)

    done = False
    while done is False:
        status, done = downloader.next_chunk()
       # print("Download %d%%." % int(status.progress() * 100))

    return fh, file_id

# %%
fh, file_id = gdrive_get_file("Product Catalog")
ingredients_df = pd.read_excel(fh)
ingredients_df
# Out:
#                                         handleId fieldType  \
# 0   product_74e39883-1aeb-6afa-582b-5e56204a8b66   Product
# 1   product_fbebda12-724b-f81e-a4d4-27cbe1a7649b   Product
# 2   product_2f5c5913-aab6-3f27-6763-92b090c488ae   Product
# 3   product_8a18ba0b-6644-abbe-f28a-a294ba2f5e0b   Product
# 4   product_1ae43c94-4e48-40e7-1fcc-8ea34c201545   Product
# 5   product_9dc51752-8d41-ded9-4a3c-f0dc1948cb28   Product
# 6   product_a1da0cad-692b-fb0b-f0f2-e669e594dfe5   Product
# 7   product_59124974-9c1c-ae21-b044-ecaae2732d70   Product
# 8   product_5340fa2a-66ba-bd30-1eb1-5d96fad9d2cc   Product
# 9   product_cca60166-30ad-2605-5d57-8b5284bb7cd5   Product
# 10  product_77bab359-494c-9f2a-0920-b2e21dc03e19   Product
# 11  product_5c63f69b-80bb-4e3f-04e3-766460525cb3   Product
# 12  product_3b2f40db-98e2-0d61-f268-eb218f9e670c   Product
# 13  product_ae62bbf6-bbf7-c7c7-cecb-9ed365ac451a   Product
# 14  product_d7c2b4ca-bc12-0261-a30b-fef440a6a274   Product
# 15  product_fc72bd33-5f0a-6814-7b4e-b7c80e4f45c2   Product
# 16  product_dcc56254-c55c-753c-35b2-a387ef7ef61d   Product
# 17  product_c5704f51-e57f-1a1f-07ca-9dd3102ef445   Product
# 18  product_e52cbde9-1abe-d104-f5d1-362ab679930d   Product
# 19  product_4c1468ab-5c68-435b-af16-a53f122f5c51   Product
# 20  product_40822a03-b54a-a9e9-cf0e-44d7ee9b077b   Product
# 21  product_f7362a24-d925-545f-e1a1-d8d808aa1ac9   Product
# 22  product_ff45fe55-fbca-3818-235e-981480f624c2   Product
# 23  product_0ae30ab4-d584-b968-5ed9-a1320488ca91   Product
# 24  product_0bddf87a-0866-9abb-67f4-6f46e4376732   Product
#
#                                        name  \
# 0                      Courageous Oil Serum
# 1              SO Confidence Oil Serum 30ml
# 2                   SO Courageous Man Cream
# 3                 SO Confidence Night Cream
# 4                   SO Confidence Day Cream
# 5    Hand Sanitiser 30ml glass spray bottle
# 6                  Courageous Man Cream 30g
# 7   Hand Sanitiser 100ml glass spray bottle
# 8                   Confidence 2 Birds 30ml
# 9        Confidence Goodness Pack 10ml each
# 10           Confidence Intro Set 30ml each
# 11         Confidence Cleanse Kit 30ml each
# 12           Reusable Bamboo Cleansing Pads
# 13            5 Thieves Essential Oil Blend
# 14        Confidence Hydrate & Moisture Set
# 15      Confidence Moisturiser Set 30g each
# 16        Confidence Complete Set 30ml each
# 17          Confidence Hydration Serum 30ml
# 18                    Confidence Toner 30ml
# 19         Confidence Cleansing Lotion 30ml
# 20             Confidence Oil Cleanser 30ml
# 21                                     Mist
# 22                Confidence Oil Serum 30ml
# 23               Confidence Night Cream 30g
# 24                 Confidence Day Cream 30g
#
#                                           description  \
# 0   <p>We haven't left the men out! &nbsp;We can f...
# 1   <p>To reward our faithful Customers we offer d...
# 2   <p>To reward our faithful Customers we offer d...
# 3   <p>To reward our faithful Customers we offer d...
# 4   <p>To reward our faithful Customers we offer d...
# 5   <p>Our Hand Sanitiser is made using 80% Bioeth...
# 6   <p>Provides the nourishment and moisturising b...
# 7   <p>Our Hand Sanitiser is made using 80% Bioeth...
# 8   2 Birds combines two of our products in one, o...
# 9   <p>Our Goodness Pack&nbsp;includes our 10ml Oi...
# 10  <p>Save a little by purchasing our Intro set! ...
# 11  <p>If you are a fan of the Korean double clean...
# 12  <p>This pack of 18 Bamboo Cleansing Pads can b...
# 13  <p>Jojoba (simmondsia&nbsp;chinensis) Seed Oil...
# 14  <p>Save a little by purchasing our Hydrate &am...
# 15  <p>Purchase the Day Cream and the Night Cream ...
# 16  <p>Save a little by purchasing the whole set! ...
# 17  <p>Our hydration serum is formulated and blend...
# 18  <p>Toning&nbsp;provides hydration and nourishm...
# 19  <p>Removes buildup of dirt,&nbsp;bacteria,&nbs...
# 20  <p>Removes daily buildup and makeup. &nbsp;Oil...
# 21  <p>Provides hydration and the added&nbsp;benef...
# 22  <p>Hand blended to suit your skin's needs with...
# 23  <p>Provides the nourishment and moisturising b...
# 24  <p>Provides the nourishment and moisturising b...
#
#                                       productImageUrl  \
# 0     c8529a_d051250f77a64b98ba657febe6c2bf7f~mv2.jpg
# 1     c8529a_ce4088b903f042e4b3c56c62b4a8351e~mv2.jpg
# 2     c8529a_a9080e94a3e743c7a8f14c0b610d7bd3~mv2.png
# 3     c8529a_c445020ab3ef475db6449fa8e9f11102~mv2.png
# 4     c8529a_15c7dad9661641eaa5b20a8762966945~mv2.png
# 5     c8529a_abdf0ce7e4634c559ec059883d868d22~mv2.jpg
# 6     c8529a_ba1e9e439ba94ecbb25da9bc88f5e785~mv2.png
# 7     c8529a_db4230fb4931454b94cbfff8e708cd8f~mv2.jpg
# 8     c8529a_b4b1adc97a554484a4d73c3df8319482~mv2.png
# 9   c8529a_f69b74e4ca1d47d091c8c7e0b9125020~mv2.pn...
# 10    c8529a_c098b098cf5d4b8688232019ec6dc527~mv2.jpg
# 11    c8529a_a40911e32d5849319dad8a562c80a02a~mv2.jpg
# 12    c8529a_333e91a80c664e938d36dd9b66411670~mv2.png
# 13    c8529a_b48fbcef5e194e1c8d4a931b3a0c1fed~mv2.png
# 14    c8529a_e5064b6463d04f0d9d5a8e7116e5b029~mv2.jpg
# 15    c8529a_f8a17cff0037485ab0a4490697c94e37~mv2.png
# 16    c8529a_cc965e6f77594342a8354b2cad581d43~mv2.jpg
# 17    c8529a_2eb8d14ecbdc424dbb5e35bbfcbb96cb~mv2.png
# 18    c8529a_42b61d54e65c47899a15a9242d067fb7~mv2.png
# 19    c8529a_b06c3d21578443edb83f000cf4499cb4~mv2.png
# 20    c8529a_968a7e35ef344ed1992642c4f508304d~mv2.png
# 21  c8529a_6023b4ede0e64bcaa39fa8fc64a78a94~mv2_d_...
# 22    c8529a_5345fb528cfe43d68b1831c3b6fa1d12~mv2.png
# 23    c8529a_27c58e232c5f4b07a119f82d2abd55d3~mv2.png
# 24    c8529a_50f44473205c4189b727cb3ba4dd1abb~mv2.png
#
#                                            collection  sku  ribbon  price  \
# 0                    Courageous Collection;Oil Serums  NaN     NaN  30.00
# 1                         Subsequent Order Collection  NaN     NaN  19.99
# 2                         Subsequent Order Collection  NaN     NaN  29.99
# 3                         Subsequent Order Collection  NaN     NaN  29.99
# 4                         Subsequent Order Collection  NaN     NaN  29.99
# 5                                     Hand Sanitisers  NaN     NaN   7.99
# 6                  Courageous Collection;Moisturisers  NaN     NaN  45.00
# 7                                     Hand Sanitisers  NaN     NaN  18.99
# 8   Confidence Collection;Toners & High Performanc...  NaN     NaN  23.00
# 9        Confidence Collection;Sets;Travel/Trial Size  NaN     NaN  30.00
# 10                                               Sets  NaN     NaN  70.00
# 11                                     Cleansers;Sets  NaN     NaN  38.70
# 12                                                NaN  NaN     NaN  20.00
# 13                                                NaN  NaN     NaN  26.99
# 14                                               Sets  NaN     NaN  49.00
# 15                                               Sets  NaN     NaN  85.00
# 16                                               Sets  NaN     NaN  99.00
# 17  Confidence Collection;Toners & High Performanc...  NaN     NaN  23.00
# 18  Confidence Collection;Toners & High Performanc...  NaN     NaN  18.00
# 19                    Cleansers;Confidence Collection  NaN     NaN  18.00
# 20                    Cleansers;Confidence Collection  NaN     NaN  25.00
# 21                                                NaN  NaN     NaN  16.00
# 22                   Confidence Collection;Oil Serums  NaN     NaN  30.00
# 23                 Confidence Collection;Moisturisers  NaN     NaN  45.00
# 24                 Confidence Collection;Moisturisers  NaN     NaN  45.00
#
#     surcharge  ...  additionalInfoTitle5  \
# 0         NaN  ...        Privacy Policy
# 1         NaN  ...                   NaN
# 2         NaN  ...                   NaN
# 3         NaN  ...                   NaN
# 4         NaN  ...                   NaN
# 5         NaN  ...          Terms Of Use
# 6         NaN  ...        Privacy Policy
# 7         NaN  ...          Terms Of Use
# 8         NaN  ...        Privacy Policy
# 9         NaN  ...        Privacy Policy
# 10        NaN  ...        Privacy Policy
# 11        NaN  ...        Privacy Policy
# 12        NaN  ...                   NaN
# 13        NaN  ...                   NaN
# 14        NaN  ...        Privacy Policy
# 15        NaN  ...        Privacy Policy
# 16        NaN  ...        Privacy Policy
# 17        NaN  ...        Privacy Policy
# 18        NaN  ...        Privacy Policy
# 19        NaN  ...        Privacy Policy
# 20        NaN  ...        Privacy Policy
# 21        NaN  ...                   NaN
# 22        NaN  ...        Privacy Policy
# 23        NaN  ...        Privacy Policy
# 24        NaN  ...        Privacy Policy
#
#                            additionalInfoDescription5  additionalInfoTitle6  \
# 0   <p>Privacy Policy for Website</p>\n\n<p>Privac...          Product Type
# 1                                                 NaN                   NaN
# 2                                                 NaN                   NaN
# 3                                                 NaN                   NaN
# 4                                                 NaN                   NaN
# 5   <p><em>Third Party Links</em></p>\n\n<p>The We...        Privacy Policy
# 6   <p>Privacy Policy for Website</p>\n\n<p>Privac...          Product Type
# 7   <p><em>Third Party Links</em></p>\n\n<p>The We...        Privacy Policy
# 8   <p>Privacy Policy for Website</p>\n\n<p>Privac...          Product Type
# 9   <p>Privacy Policy for Website</p>\n\n<p>Privac...     Products Included
# 10  <p>Privacy Policy for Website</p>\n\n<p>Privac...     Products Included
# 11  <p>Privacy Policy for Website</p>\n\n<p>Privac...     Products Included
# 12                                                NaN                   NaN
# 13                                                NaN                   NaN
# 14  <p>Privacy Policy for Website</p>\n\n<p>Privac...     Products Included
# 15  <p><em>Privacy Policy for Website</em></p>\n\n...     Products Included
# 16  <p>Privacy Policy for Website</p>\n\n<p>Privac...     Products Included
# 17  <p>Privacy Policy for Website</p>\n\n<p>Privac...          Product Type
# 18  <p>Privacy Policy for Website</p>\n\n<p>Privac...          Product Type
# 19  <p>Privacy Policy for Website</p>\n\n<p>Privac...          Product Type
# 20  <p>Privacy Policy for Website</p>\n\n<p>Privac...          Product Type
# 21                                                NaN                   NaN
# 22  <p>Privacy Policy for Website</p>\n\n<p>Privac...          Product Type
# 23  <p>Privacy Policy for Website</p>\n\n<p>Privac...          Product Type
# 24  <p>Privacy Policy for Website</p>\n\n<p>Privac...          Product Type
#
#                            additionalInfoDescription6  customTextField1  \
# 0                                  <p>Oil Serum</p>\n               NaN
# 1                                                 NaN               NaN
# 2                                                 NaN               NaN
# 3                                                 NaN               NaN
# 4                                                 NaN               NaN
# 5   <p>Privacy Policy for Website</p>\n\n<p>Privac...               NaN
# 6                                  <p>Man Cream</p>\n               NaN
# 7   <p>Privacy Policy for Website</p>\n\n<p>Privac...               NaN
# 8                     <p>Hydration Serum, Toner</p>\n               NaN
# 9   <p>Cleansing Oil, Oil Serum, Hydration Serum</...               NaN
# 10  <p>Oil Cleanser, Oil Serum, Hydration Serum</p>\n               NaN
# 11            <p>Oil Cleanser, Cleansing Lotion</p>\n               NaN
# 12                                                NaN               NaN
# 13                                                NaN               NaN
# 14                <p>Oil Serum, Hydration Serum</p>\n               NaN
# 15                    <p>Day Cream, Night Cream</p>\n               NaN
# 16  <p>Oil Cleanser, Cleansing Lotion, Toner, Oil ...               NaN
# 17                           <p>Hydration Serum</p>\n               NaN
# 18                                     <p>Toner</p>\n               NaN
# 19                          <p>Cleansing Lotion</p>\n               NaN
# 20                              <p>Oil Cleanser</p>\n               NaN
# 21                                                NaN               NaN
# 22                                 <p>Oil Serum</p>\n               NaN
# 23                               <p>Night Cream</p>\n               NaN
# 24                                 <p>Day Cream</p>\n               NaN
#
#     customTextCharLimit1  customTextMandatory1  customTextField2  \
# 0                    NaN                   NaN               NaN
# 1                    NaN                   NaN               NaN
# 2                    NaN                   NaN               NaN
# 3                    NaN                   NaN               NaN
# 4                    NaN                   NaN               NaN
# 5                    NaN                   NaN               NaN
# 6                    NaN                   NaN               NaN
# 7                    NaN                   NaN               NaN
# 8                    NaN                   NaN               NaN
# 9                    NaN                   NaN               NaN
# 10                   NaN                   NaN               NaN
# 11                   NaN                   NaN               NaN
# 12                   NaN                   NaN               NaN
# 13                   NaN                   NaN               NaN
# 14                   NaN                   NaN               NaN
# 15                   NaN                   NaN               NaN
# 16                   NaN                   NaN               NaN
# 17                   NaN                   NaN               NaN
# 18                   NaN                   NaN               NaN
# 19                   NaN                   NaN               NaN
# 20                   NaN                   NaN               NaN
# 21                   NaN                   NaN               NaN
# 22                   NaN                   NaN               NaN
# 23                   NaN                   NaN               NaN
# 24                   NaN                   NaN               NaN
#
#     customTextCharLimit2  customTextMandatory2
# 0                    NaN                   NaN
# 1                    NaN                   NaN
# 2                    NaN                   NaN
# 3                    NaN                   NaN
# 4                    NaN                   NaN
# 5                    NaN                   NaN
# 6                    NaN                   NaN
# 7                    NaN                   NaN
# 8                    NaN                   NaN
# 9                    NaN                   NaN
# 10                   NaN                   NaN
# 11                   NaN                   NaN
# 12                   NaN                   NaN
# 13                   NaN                   NaN
# 14                   NaN                   NaN
# 15                   NaN                   NaN
# 16                   NaN                   NaN
# 17                   NaN                   NaN
# 18                   NaN                   NaN
# 19                   NaN                   NaN
# 20                   NaN                   NaN
# 21                   NaN                   NaN
# 22                   NaN                   NaN
# 23                   NaN                   NaN
# 24                   NaN                   NaN
#
# [25 rows x 51 columns]

# %%
# Push file to gdrive
def push_file(self, file_id, filename, path, **kwargs):
    """ Upload to google drive, update existing file
    """
    file_metadata = {"name": filename}

    media = MediaFileUpload(path, 
        mimetype="application/vnd.openxmlformats-officedocument.spreadsheetml.sheet")
    
    if kwargs.get("action") == "update":
        f = self.service.files().update(fileId=file_id, 
                                        body=file_metadata,
                                        media_body=media,
                                        fields="id").execute()
    else:
        f = self.service.files().create(body=file_metadata,
                                        media_body=media,
                                        fields="id").execute()

# %%
# Swap keys and values for filled in cells
cell_items = list(cell_dict.items())
cell_items.sort(key=lambda x: x[1], reverse=True)
ingredient_str = ""
for i in range(len(cell_items)):
    index = cell_items[i][0][1:]
    ingredient_name = sheet["B"+index].value
    # get inci
    inci = ingredients_df.loc[ingredient_name]["INGREDIENT INCI NAME"]
    ingredient_str += inci + ", "
    
# Store into df
infoSheet_df["Ingredients"] = ingredient_str
infoSheet_df
# Out:
#                              Recommendations For Use  \
# 0  Simple instructions can be found on each produ...
#
#                                     For Best Results  \
# 0  It is recommended that you strip back your ski...
#
#                          Care & Storage Instructions  \
# 0  Store below 25 degrees celsius.  Keep out of d...
#
#                     Directions & Warnings Before Use  \
# 0  Apply a patch test first in the area of use.  ...
#
#                                          Ingredients  \
# 0  Argania spinosa (Argan) oil (certified organic...
#
#                                  Our promises to you  \
# 0  Store below 25 degrees celsius. Keep out of di...
#
#                                Use By & Besfore Date
# 0  This blend must be used within …. months of bl...

# %%
pip install pypandoc
# Out:
# Collecting pypandoc
#   Downloading pypandoc-1.5.tar.gz (26 kB)
# Requirement already satisfied: setuptools in c:\users\jerry\appdata\local\programs\python\python37\lib\site-packages (from pypandoc) (41.2.0)
# Requirement already satisfied: pip>=8.1.0 in c:\users\jerry\appdata\local\programs\python\python37\lib\site-packages (from pypandoc) (20.1.1)
# Requirement already satisfied: wheel>=0.25.0 in c:\users\jerry\appdata\local\programs\python\python37\lib\site-packages (from pypandoc) (0.34.2)
# Building wheels for collected packages: pypandoc
#   Building wheel for pypandoc (setup.py): started
#   Building wheel for pypandoc (setup.py): finished with status 'done'
#   Created wheel for pypandoc: filename=pypandoc-1.5-py3-none-any.whl size=17042 sha256=7bd59bf2a112aec7355ba4526c98d23997b92d8024438e14ef17b2467a549c24
#   Stored in directory: c:\users\jerry\appdata\local\pip\cache\wheels\06\a7\1d\3259fbf0089b15d491d9166b97de3a23d1f915bf7591abafc7
# Successfully built pypandoc
# Installing collected packages: pypandoc
# Successfully installed pypandoc-1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

ingredients_df = pd.read_csv("C:/Users/jerry/Desktop/Restored To Eden/RTE Ingredients Database.csv")
ingredients_df.set_index("INGREDIENT COMMON NAME", inplace=True)
ingredients_df
# Out:
#                                                                         INGREDIENT INCI NAME  \
# INGREDIENT COMMON NAME
# Acai Oil Certified Organic                   Euterpe oleracea (Acai) oil (certified organic)
# Aloe Vera Juice                                           Aloe Barbadensis (Aloe Vera) juice
# Alpinia Leaf                                                                             NaN
# Alpinia Root                                                                             NaN
# Apricot Kernel Oil                         Prunus armeniaca (Apricot) kernel oil (certifi...
# ...                                                                                      ...
# Vitamin E Natural (Mixed tocopherols 70%)          Mixed tocopherols 70% (Vitamin E natural)
# Walnut Oil                                                                               NaN
# White Willow Bark                                                                        NaN
# Witch Hazel Infused Water                                               Hamamelis virginiana
# Ylang Ylang                                Cananga odorata (Ylang Ylang) flower essential...
#
#                                           In Stock  \
# INGREDIENT COMMON NAME
# Acai Oil Certified Organic                     Yes
# Aloe Vera Juice                                Yes
# Alpinia Leaf                                   NaN
# Alpinia Root                                   NaN
# Apricot Kernel Oil                             Yes
# ...                                            ...
# Vitamin E Natural (Mixed tocopherols 70%)      Yes
# Walnut Oil                                      No
# White Willow Bark                              NaN
# Witch Hazel Infused Water                      Yes
# Ylang Ylang                                    Yes
#
#                                            Quantity in Stock (in grams)  \
# INGREDIENT COMMON NAME
# Acai Oil Certified Organic                                          NaN
# Aloe Vera Juice                                                     NaN
# Alpinia Leaf                                                        NaN
# Alpinia Root                                                        NaN
# Apricot Kernel Oil                                                  NaN
# ...                                                                 ...
# Vitamin E Natural (Mixed tocopherols 70%)                           NaN
# Walnut Oil                                                          NaN
# White Willow Bark                                                   NaN
# Witch Hazel Infused Water                                           NaN
# Ylang Ylang                                                         NaN
#
#                                           Supplier Name    CAS NO.  \
# INGREDIENT COMMON NAME
# Acai Oil Certified Organic                          AWO        NaN
# Aloe Vera Juice                                      ND        NaN
# Alpinia Leaf                                        NaN        NaN
# Alpinia Root                                        NaN        NaN
# Apricot Kernel Oil                                  AWO        NaN
# ...                                                 ...        ...
# Vitamin E Natural (Mixed tocopherols 70%)           AWO  7695-91-2
# Walnut Oil                                          NaN        NaN
# White Willow Bark                                   NaN        NaN
# Witch Hazel Infused Water                           NaN        NaN
# Ylang Ylang                                         NaN        NaN
#
#                                           NICNAS Check Completed  \
# INGREDIENT COMMON NAME
# Acai Oil Certified Organic                                    No
# Aloe Vera Juice                                              Yes
# Alpinia Leaf                                                 NaN
# Alpinia Root                                                 NaN
# Apricot Kernel Oil                                           Yes
# ...                                                          ...
# Vitamin E Natural (Mixed tocopherols 70%)                     No
# Walnut Oil                                                   NaN
# White Willow Bark                                            NaN
# Witch Hazel Infused Water                                    Yes
# Ylang Ylang                                                  Yes
#
#                                                  Product Type  \
# INGREDIENT COMMON NAME
# Acai Oil Certified Organic                          Anhydrous
# Aloe Vera Juice                                           NaN
# Alpinia Leaf                                              NaN
# Alpinia Root                                              NaN
# Apricot Kernel Oil                         Anhydrous,Emulsion
# ...                                                       ...
# Vitamin E Natural (Mixed tocopherols 70%)  Anhydrous,Emulsion
# Walnut Oil                                                NaN
# White Willow Bark                                         NaN
# Witch Hazel Infused Water                                 NaN
# Ylang Ylang                                Anhydrous,Emulsion
#
#                                                                                    Skin Type  \
# INGREDIENT COMMON NAME
# Acai Oil Certified Organic                 Dry Skin,Sensitive & Eczema Prone Skin,Mature ...
# Aloe Vera Juice                                                          Mature & Aging Skin
# Alpinia Leaf                                                             Mature & Aging Skin
# Alpinia Root                                                             Mature & Aging Skin
# Apricot Kernel Oil                         Dry Skin,Sensitive & Eczema Prone Skin,Mature ...
# ...                                                                                      ...
# Vitamin E Natural (Mixed tocopherols 70%)                                Mature & Aging Skin
# Walnut Oil                                                                               NaN
# White Willow Bark                                              Sensitive & Eczema Prone Skin
# Witch Hazel Infused Water                                      Sensitive & Eczema Prone Skin
# Ylang Ylang                                                  Dry Skin,Oily & Acne Prone Skin
#
#                                                                TYPE OF INGREDIENT  \
# INGREDIENT COMMON NAME
# Acai Oil Certified Organic                             Carrier Oil,anhydrous base
# Aloe Vera Juice                                  Extract,aqueous high performance
# Alpinia Leaf                                     Extract,aqueous high performance
# Alpinia Root                                                                  NaN
# Apricot Kernel Oil                                     Carrier Oil,anhydrous base
# ...                                                                           ...
# Vitamin E Natural (Mixed tocopherols 70%)  Antioxidant,anhydrous high performance
# Walnut Oil                                             Carrier Oil,anhydrous base
# White Willow Bark                                Extract,aqueous high performance
# Witch Hazel Infused Water                                Aqueous high performance
# Ylang Ylang                                                         Essential Oil
#
#                                           ESSENTIAL OIL NOTE  ... VISCOSITY  \
# INGREDIENT COMMON NAME                                        ...
# Acai Oil Certified Organic                               NaN  ...     Light
# Aloe Vera Juice                                          NaN  ...       NaN
# Alpinia Leaf                                             NaN  ...       NaN
# Alpinia Root                                             NaN  ...       NaN
# Apricot Kernel Oil                                       NaN  ...     Light
# ...                                                      ...  ...       ...
# Vitamin E Natural (Mixed tocopherols 70%)                NaN  ...       NaN
# Walnut Oil                                               NaN  ...       NaN
# White Willow Bark                                        NaN  ...       NaN
# Witch Hazel Infused Water                                NaN  ...       NaN
# Ylang Ylang                                             Base  ...       NaN
#
#                                           ABSORPTION RATE COMEDOGENIC RATING  \
# INGREDIENT COMMON NAME
# Acai Oil Certified Organic                           Fast                2.0
# Aloe Vera Juice                                       NaN                NaN
# Alpinia Leaf                                          NaN                NaN
# Alpinia Root                                          NaN                NaN
# Apricot Kernel Oil                                   Fast                2.0
# ...                                                   ...                ...
# Vitamin E Natural (Mixed tocopherols 70%)             NaN                NaN
# Walnut Oil                                         Medium                2.0
# White Willow Bark                                     NaN                NaN
# Witch Hazel Infused Water                             NaN                NaN
# Ylang Ylang                                           NaN                NaN
#
#                                           Composition  \
# INGREDIENT COMMON NAME
# Acai Oil Certified Organic                        NaN
# Aloe Vera Juice                                   NaN
# Alpinia Leaf                                      NaN
# Alpinia Root                                      NaN
# Apricot Kernel Oil                                NaN
# ...                                               ...
# Vitamin E Natural (Mixed tocopherols 70%)         NaN
# Walnut Oil                                        NaN
# White Willow Bark                                 NaN
# Witch Hazel Infused Water                         NaN
# Ylang Ylang                                       NaN
#
#                                           Recommended Concentration Allergens  \
# INGREDIENT COMMON NAME
# Acai Oil Certified Organic                                      NaN       NaN
# Aloe Vera Juice                                                 NaN       NaN
# Alpinia Leaf                                                    NaN       NaN
# Alpinia Root                                                    NaN       NaN
# Apricot Kernel Oil                                              NaN       NaN
# ...                                                             ...       ...
# Vitamin E Natural (Mixed tocopherols 70%)                   0.5%-2%       NaN
# Walnut Oil                                                      NaN       NaN
# White Willow Bark                                               NaN       NaN
# Witch Hazel Infused Water                                       NaN       NaN
# Ylang Ylang                                                     NaN       NaN
#
#                                                                          Relevant References  \
# INGREDIENT COMMON NAME
# Acai Oil Certified Organic                                                               NaN
# Aloe Vera Juice                            Aloe Vera powder and purified Aqua - and prese...
# Alpinia Leaf                                                                             NaN
# Alpinia Root                                                                             NaN
# Apricot Kernel Oil                         Review Article\nPolyphenols as active ingredie...
# ...                                                                                      ...
# Vitamin E Natural (Mixed tocopherols 70%)                                                NaN
# Walnut Oil                                                                               NaN
# White Willow Bark                                                                        NaN
# Witch Hazel Infused Water                                                                NaN
# Ylang Ylang                                                                              NaN
#
#                                                                  Other Important Information  \
# INGREDIENT COMMON NAME
# Acai Oil Certified Organic                                                               NaN
# Aloe Vera Juice                                                                          NaN
# Alpinia Leaf                                                                             NaN
# Alpinia Root                                                                             NaN
# Apricot Kernel Oil                         Thinner consistency\nCleansing properties\n\nA...
# ...                                                                                      ...
# Vitamin E Natural (Mixed tocopherols 70%)  Components: Mixed Tocopherols (d-alpha-, d-bet...
# Walnut Oil                                                                               NaN
# White Willow Bark                                                                        NaN
# Witch Hazel Infused Water                                                                NaN
# Ylang Ylang                                Contracindications : New Directions Aromatics ...
#
#                                             4   K
# INGREDIENT COMMON NAME
# Acai Oil Certified Organic                NaN NaN
# Aloe Vera Juice                           NaN NaN
# Alpinia Leaf                              NaN NaN
# Alpinia Root                              NaN NaN
# Apricot Kernel Oil                        NaN NaN
# ...                                        ..  ..
# Vitamin E Natural (Mixed tocopherols 70%) NaN NaN
# Walnut Oil                                NaN NaN
# White Willow Bark                         NaN NaN
# Witch Hazel Infused Water                 NaN NaN
# Ylang Ylang                               NaN NaN
#
# [110 rows x 25 columns]

# %% [markdown]
# # Config File Testing

# %%
import json
# Json is a dictionary in python
Config = {"ConstraintSettings": {
    "DayCream": {"Viscosity": "Light", "Absorbency": "Fast"},
    "ManCream": {"Viscosity": "Medium", "Absorbency": "Medium"},
    "NightCream": {"Viscosity": "Heavy", "Absorbency": "Slow"},
    "OilCleanser": {"Viscosity": "Medium", "Absorbency": "Medium"}
},
          "Viscosity": ["light", "medium", "heavy"],
          "Absorbency": ["slow", "medium", "fast"],
          "ComedogenicRating": [0, 1, 2 ,3 ,4 ,5]}
# Writing config file to output
json_obj = json.dumps(Config, indent=4)
with open("config.json", "w") as outfile:
    outfile.write(json_obj)
    
# Reading config file
with open("config.json") as json_file:
    data = json.load(json_file)
print(data)
# Out:
# {'ConstraintSettings': {'DayCream': {'Viscosity': 'Light', 'Absorbency': 'Fast'}, 'ManCream': {'Viscosity': 'Medium', 'Absorbency': 'Medium'}, 'NightCream': {'Viscosity': 'Heavy', 'Absorbency': 'Slow'}, 'OilCleanser': {'Viscosity': 'Medium', 'Absorbency': 'Medium'}}, 'Viscosity': ['light', 'medium', 'heavy'], 'Absorbency': ['slow', 'medium', 'fast'], 'ComedogenicRating': [0, 1, 2, 3, 4, 5]}

# %% [markdown]
# # Find distance between 2 lines

# %%
# Get coordinates by coverting categorical data to numeric
# Line coords: (x=Viscosity, y=Absorbency, z=Comedogenic rating)
product_type = "OilCleanser"
# Find coordinates of points (a) for optimum
try:
    x1_str = data["ConstraintSettings"][product_type]["Viscosity"].lower()
    x1 = [option.lower() for option in data["Viscosity"]].index(x1_str)
except:
    x1 = 0

try:
    y1_str = data["ConstraintSettings"][product_type]["Absorbency"].lower()
    y1 = [option.lower() for option in data["Absorbency"]].index(y1_str)
except:
    y1 = 0

try:
    z1_str = data["ConstraintSettings"][product_type]["ComedogenicRating"].lower()
    z1 = [option.lower() for option in data["ComedogenicRating"]].index(z1_str)
except:
    z1 = 0
    
a1 = (x1, y1, z1)

# a2 is the point of the selected ingredient list - take average of all ingredients?
# Since all points go through origin the directional vector is just the vector itself
# Out:
# (1, 1, 0)

# %%
import numpy as np
# distance between 2 skew lines
# Points
a1 = [0, 2, -1]
a2 = [1, 0, -1]
# Direction vectors
b1 = [1, 1, 2]
b2 = [1, 1, 3]

PQ = []
for i in range(len(a1)):
    PQ.append(a2[i] - a1[i])
    
np.linalg.norm(np.dot(PQ, np.cross(b1, b2))) / np.linalg.norm(np.cross(b2, b1))
# Out:
# 2.1213203435596424

# %%
class a:
    val = 10
class b:
    def __init__(self, a):
        self.a = a
    
aob = a()
bob = b(aob)

# %%
bob.a.val = 10
print(bob.a.val)
print(aob.val)
# Out:
# 10
# 10

# %%
import re

re.split("\s*[,]\s*", "carrier oil,      aqueous")
# Out:
# ['carrier oil', 'aqueous']

# %%
import pandas as pd

ingredFname = "C:/Users/jerry/Desktop/Restored To Eden/Ingredients.csv"
ingredients_df = pd.read_csv(ingredFname)
ingredients_df.fillna("", inplace = True)
ingredients_df = ingredients_df.applymap(lambda x:str(x).upper())

# %%
ingredients_df
# Out:
#                         INGREDIENT COMMON NAME  \
# 0                   ACAI OIL CERTIFIED ORGANIC
# 1                              ALOE VERA JUICE
# 2                                 ALPINIA LEAF
# 3                                 ALPINIA ROOT
# 4                           APRICOT KERNEL OIL
# ..                                         ...
# 105  VITAMIN E NATURAL (MIXED TOCOPHEROLS 70%)
# 106                                 WALNUT OIL
# 107                          WHITE WILLOW BARK
# 108                  WITCH HAZEL INFUSED WATER
# 109                                YLANG YLANG
#
#                                   INGREDIENT INCI NAME In Stock  \
# 0      EUTERPE OLERACEA (ACAI) OIL (CERTIFIED ORGANIC)      YES
# 1                   ALOE BARBADENSIS (ALOE VERA) JUICE      YES
# 2
# 3
# 4    PRUNUS ARMENIACA (APRICOT) KERNEL OIL (CERTIFI...      YES
# ..                                                 ...      ...
# 105          MIXED TOCOPHEROLS 70% (VITAMIN E NATURAL)      YES
# 106                                                          NO
# 107
# 108                               HAMAMELIS VIRGINIANA      YES
# 109  CANANGA ODORATA (YLANG YLANG) FLOWER ESSENTIAL...      YES
#
#     Quantity in Stock (in grams) Supplier Name    CAS NO.  \
# 0                                          AWO
# 1                                           ND
# 2
# 3
# 4                                          AWO
# ..                           ...           ...        ...
# 105                                        AWO  7695-91-2
# 106
# 107
# 108
# 109
#
#     NICNAS Check Completed        Product Type  \
# 0                       NO           ANHYDROUS
# 1                      YES
# 2
# 3
# 4                      YES  ANHYDROUS,EMULSION
# ..                     ...                 ...
# 105                     NO  ANHYDROUS,EMULSION
# 106
# 107
# 108                    YES
# 109                    YES  ANHYDROUS,EMULSION
#
#                                              Skin Type  \
# 0    DRY SKIN,SENSITIVE & ECZEMA PRONE SKIN,MATURE ...
# 1                                  MATURE & AGING SKIN
# 2                                  MATURE & AGING SKIN
# 3                                  MATURE & AGING SKIN
# 4    DRY SKIN,SENSITIVE & ECZEMA PRONE SKIN,MATURE ...
# ..                                                 ...
# 105                                MATURE & AGING SKIN
# 106
# 107                      SENSITIVE & ECZEMA PRONE SKIN
# 108                      SENSITIVE & ECZEMA PRONE SKIN
# 109                    DRY SKIN,OILY & ACNE PRONE SKIN
#
#                          TYPE OF INGREDIENT  ... VISCOSITY ABSORPTION RATE  \
# 0                CARRIER OIL,ANHYDROUS BASE  ...     LIGHT            FAST
# 1          EXTRACT,AQUEOUS HIGH PERFORMANCE  ...
# 2          EXTRACT,AQUEOUS HIGH PERFORMANCE  ...
# 3                                            ...
# 4                CARRIER OIL,ANHYDROUS BASE  ...     LIGHT            FAST
# ..                                      ...  ...       ...             ...
# 105  ANTIOXIDANT,ANHYDROUS HIGH PERFORMANCE  ...
# 106              CARRIER OIL,ANHYDROUS BASE  ...                    MEDIUM
# 107        EXTRACT,AQUEOUS HIGH PERFORMANCE  ...
# 108                AQUEOUS HIGH PERFORMANCE  ...
# 109                           ESSENTIAL OIL  ...
#
#     COMEDOGENIC RATING Composition Recommended Concentration Allergens  \
# 0                  2.0
# 1
# 2
# 3
# 4                  2.0
# ..                 ...         ...                       ...       ...
# 105                                                  0.5%-2%
# 106                2.0
# 107
# 108
# 109
#
#                                    Relevant References  \
# 0
# 1    ALOE VERA POWDER AND PURIFIED AQUA - AND PRESE...
# 2
# 3
# 4    REVIEW ARTICLE\nPOLYPHENOLS AS ACTIVE INGREDIE...
# ..                                                 ...
# 105
# 106
# 107
# 108
# 109
#
#                            Other Important Information 4  K
# 0
# 1
# 2
# 3
# 4    THINNER CONSISTENCY\nCLEANSING PROPERTIES\n\nA...
# ..                                                 ... .. ..
# 105  COMPONENTS: MIXED TOCOPHEROLS (D-ALPHA-, D-BET...
# 106
# 107
# 108
# 109  CONTRACINDICATIONS : NEW DIRECTIONS AROMATICS ...
#
# [110 rows x 26 columns]

# %%
lst = {"w":[0,1,6,55,4,94]}
lst["w"].pop(2)
# Out:
# 6

# %%
lst
# Out:
# {'w': [0, 1, 55, 4, 94]}
